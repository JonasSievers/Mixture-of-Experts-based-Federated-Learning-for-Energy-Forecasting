# %%
#Imports
import pandas as pd
import os
import tensorflow as tf

from keras import backend as K

import sys  
sys.path.append("../../../")  
from utils.models import *
from utils.datahandling import *
from utils.modelrunner import *
from utils.federatedrunner import *

import wandb
import logging
logging.getLogger("wandb").setLevel(logging.ERROR)
logging.getLogger('tensorflow').setLevel(logging.ERROR)

os.environ['WANDB_SILENT'] = 'true'
os.environ['WANDB_CONSOLE'] = 'off'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Out:
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Data processing

# %%
#Get data 
num_users = 30

cwd = os.path.normpath(os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))))
df = pd.read_csv(cwd+'/data/3final_data/Final_Grossload_dataset.csv', index_col='Date')
df.index = pd.to_datetime(df.index)
df.fillna(0, inplace=True)

df_array = []
for idx in range(num_users):
    df_array.append(df[[f'User{idx+1}', 'temp', 'rhum', 'wspd', 'PC1', 'hour sin', 'hour cos', f'User{idx+1}_lag_24hrs']])

df_array[0].head(1)
# Out:
#             User1  temp  rhum  wspd       PC1  hour sin  hour cos  \
# Date
# 2010-07-02  0.111   2.5  92.0   0.0 -2.641741       0.0       1.0
#
#             User1_lag_24hrs
# Date
# 2010-07-02            0.125

# %%
#Hyperparameters
sequence_length = 25
batch_size = 16
num_features = df_array[0].shape[1]
horizon = 1
max_epochs = 100

loss = tf.keras.losses.MeanSquaredError()
metrics=[
    tf.keras.metrics.RootMeanSquaredError(), 
    tf.keras.metrics.MeanAbsolutePercentageError(),
    tf.keras.metrics.MeanAbsoluteError(),
]

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10,mode='min')
timing_callback = TimingCallback()
custom_callback = CustomCallback()

callbacks=[early_stopping, timing_callback, custom_callback]

#Soft dense MoE
dense_smoe_units = 16
dense_smoe_expert_units = 8
dense_smoe_num_experts = 4
dense_smoe_all_results = pd.DataFrame(columns=["user", "architecture", "train_time", "avg_time_epoch", "mse", "rmse", "mape", "mae"])
dense_smoe_results = pd.DataFrame(columns=['architecture', 'train_time', 'avg_time_epoch', 'mse','mse_std', 'rmse','rmse_std','mape','mape_std','mae','mae_std'])

#Soft lstm MoE
lstm_smoe_units = 20
lstm_smoe_expert_units = 8
lstm_smoe_num_experts = 4
lstm_smoe_all_results = pd.DataFrame(columns=["user", "architecture", "train_time", "avg_time_epoch", "mse", "rmse", "mape", "mae"])
lstm_smoe_results = pd.DataFrame(columns=['architecture', 'train_time', 'avg_time_epoch', 'mse','mse_std', 'rmse','rmse_std','mape','mape_std','mae','mae_std'])

#topK dense MoE
dense_topmoe_units = 16
dense_topmoe_num_experts = 5
dense_topmoe_top_k = 2
dense_topmoe_expert_units = 8
dense_topmoe_all_results = pd.DataFrame(columns=["user", "architecture", "train_time", "avg_time_epoch", "mse", "rmse", "mape", "mae"])
dense_topmoe_results = pd.DataFrame(columns=['architecture', 'train_time', 'avg_time_epoch', 'mse','mse_std', 'rmse','rmse_std','mape','mape_std','mae','mae_std'])

#topK lstm MoE
lstm_topmoe_units = 20
lstm_topmoe_num_experts = 5
lstm_topmoe_top_k = 2
lstm_topmoe_expert_units = 8
lstm_topmoe_all_results = pd.DataFrame(columns=["user", "architecture", "train_time", "avg_time_epoch", "mse", "rmse", "mape", "mae"])
lstm_topmoe_results = pd.DataFrame(columns=['architecture', 'train_time', 'avg_time_epoch', 'mse','mse_std', 'rmse','rmse_std','mape','mape_std','mae','mae_std'])

# %%
#Train, Validation and Test datasets
X_train, y_train, X_val, y_val, X_test, y_test = {}, {}, {}, {}, {}, {}

#Create Train, Validation and Test datasets
for idx, df in enumerate(df_array):
    n = len(df)
    train_df = df[0:int(n*0.7)]
    val_df = df[int(n*0.7):int(n*0.9)]
    test_df = df[int(n*0.9):]

    # Min max sclaing
    train_df = min_max_scaling(train_df)
    val_df = min_max_scaling(val_df)
    test_df = min_max_scaling(test_df)

    # Sequencing
    train_sequences = create_sequences(train_df, sequence_length)
    val_sequences = create_sequences(val_df, sequence_length)
    test_sequences = create_sequences(test_df, sequence_length)

    #Split into feature and label
    X_train[f'user{idx+1}'], y_train[f'user{idx+1}'] = prepare_data(train_sequences, batch_size)
    X_val[f'user{idx+1}'], y_val[f'user{idx+1}'] = prepare_data(val_sequences, batch_size)
    X_test[f'user{idx+1}'], y_test[f'user{idx+1}'] = prepare_data(test_sequences, batch_size)

# %% [markdown]
# ### Federated Learning MoE models

# %%
federated_rounds = 2
num_rounds = 2

y = np.loadtxt(f'../../../../data/3final_data/Clusters_KMeans10_dtw.csv', delimiter=',').astype(int)
num_clusters = 10
cluster_users = {i: [] for i in range(num_clusters)}

# Iterate through each cluster
for cluster_number in range(num_clusters):
    users_in_cluster = np.where(y == cluster_number)[0] +1
    cluster_users[cluster_number] = users_in_cluster
cluster_users
# Out:
# {0: array([ 7, 14, 18, 22, 23, 25, 29], dtype=int64),
#  1: array([6], dtype=int64),
#  2: array([ 3,  4,  9, 13, 15, 19, 20, 30], dtype=int64),
#  3: array([1], dtype=int64),
#  4: array([21], dtype=int64),
#  5: array([ 2, 28], dtype=int64),
#  6: array([ 5, 10, 11, 12, 24, 26, 27], dtype=int64),
#  7: array([8], dtype=int64),
#  8: array([17], dtype=int64),
#  9: array([16], dtype=int64)}

# %%
max_epochs = 2

# %%
#soft bilstm
run_federated_benchmark_model(
    num_clusters = num_clusters,
    federated_rounds = federated_rounds,
    cluster_users = cluster_users,
    save_path = os.getcwd(),
    wb_project_name = "TS_FL_Grossload_Forecasting_Moe",
    wb_project = "TS_FL_Grossload",
    wb_model_name = "global_soft_bilstm",
    df_array = df_array,
    max_epochs = max_epochs,
    batch_size = batch_size,
    X_train = X_train,
    horizon = horizon,
    loss = loss,
    metrics = metrics,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    soft_lstm_units = lstm_smoe_units, 
    soft_lstm_num_experts = lstm_smoe_num_experts,
    soft_lstm_expert_units = lstm_smoe_expert_units,
)
evaluate_federated_benchmark_model(
    federated_rounds = federated_rounds,
    save_path = os.getcwd(),
    wb_project = "TS_FL_Grossload",
    wb_model_name = "global_soft_bilstm",
    cluster_users = cluster_users,
    num_rounds = num_rounds,
    horizon = horizon,
    batch_size = batch_size,
    metrics = metrics,
    loss = loss,
    X_train = X_train,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    df_array = df_array,
    results = lstm_smoe_results,
    all_results = lstm_smoe_all_results,
    wb_project_name="TS_FL_Grossload_Forecasting_Moe",
    soft_lstm_units = lstm_smoe_units, 
    soft_lstm_num_experts = lstm_smoe_num_experts,
    soft_lstm_expert_units = lstm_smoe_expert_units,
)
# Out:
# Started Federated training round ---------- 1 / 2
# Cluster 0:
# User 7
# User 14
# User 18
# User 22
# User 23
# User 25
# User 29
# Saved Global models
# Cluster 1:
# User 6
# Saved Global models
# Cluster 2:
# User 3
# User 4
# User 9
# User 13
# User 15
# User 19
# User 20
# User 30
# Saved Global models
# Cluster 3:
# User 1
# Saved Global models
# Cluster 4:
# User 21
# Saved Global models
# Cluster 5:
# User 2
# User 28

# %%
#topk bilstm
run_federated_benchmark_model(
    num_clusters = num_clusters,
    federated_rounds = federated_rounds,
    cluster_users = cluster_users,
    save_path = os.getcwd(),
    wb_project_name = "TS_FL_Grossload_Forecasting_Moe",
    wb_project = "TS_FL_Grossload",
    wb_model_name = "global_topk_bilstm",
    df_array = df_array,
    max_epochs = max_epochs,
    batch_size = batch_size,
    X_train = X_train,
    horizon = horizon,
    loss = loss,
    metrics = metrics,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    topk_lstm_units = lstm_topmoe_units, 
    topk_lstm_num_experts = lstm_topmoe_num_experts,
    topk_lstm_expert_units = lstm_topmoe_expert_units,
    topk_bilstm=lstm_topmoe_top_k,
)

evaluate_federated_benchmark_model(
    federated_rounds = federated_rounds,
    save_path = os.getcwd(),
    wb_project = "TS_FL_Grossload",
    wb_model_name = "global_soft_bilstm",
    cluster_users = cluster_users,
    num_rounds = num_rounds,
    horizon = horizon,
    batch_size = batch_size,
    metrics = metrics,
    loss = loss,
    X_train = X_train,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    df_array = df_array,
    results = lstm_topmoe_results,
    all_results = lstm_topmoe_all_results,
    wb_project_name="TS_FL_Grossload_Forecasting_Moe",
    topk_lstm_units = lstm_topmoe_units, 
    topk_lstm_num_experts = lstm_topmoe_num_experts,
    topk_lstm_expert_units = lstm_topmoe_expert_units,
    topk_bilstm=lstm_topmoe_top_k,
)
# Out:
# Started Federated training round ---------- 1 / 2
# Cluster 0:
# got models
# User 7
# User 14
# User 18
# User 22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 #topk bilstm
# ----> 2 run_federated_benchmark_model(
#       3     num_clusters = num_clusters,
#       4     federated_rounds = federated_rounds,
#       5     cluster_users = cluster_users,
#       6     save_path = os.getcwd(),
#       7     wb_project_name = "TS_FL_Grossload_Forecasting_Moe",
#       8     wb_project = "TS_FL_Grossload",
#       9     wb_model_name = "global_topk_bilstm",
#      10     df_array = df_array,
#      11     max_epochs = max_epochs,
#      12     batch_size = batch_size,
#      13     X_train = X_train,
#      14     horizon = horizon,
#      15     loss = loss,
#      16     metrics = metrics,
#      17     y_train = y_train,
#      18     X_val = X_val,
#      19     y_val = y_val,
#      20     X_test = X_test,
#      21     y_test = y_test,
#      22     callbacks = callbacks,
#      23     topk_lstm_units = lstm_topmoe_units,
#      24     topk_lstm_num_experts = lstm_topmoe_num_experts,
#      25     topk_lstm_expert_units = lstm_topmoe_expert_units,
#      26     topk_bilstm=lstm_topmoe_top_k,
#      27 )
#      29 evaluate_federated_benchmark_model(
#      30     federated_rounds = federated_rounds,
#      31     save_path = os.getcwd(),
#    (...)
#      54     topk_bilstm=lstm_topmoe_top_k,
#      55 )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\src\time_series\Federatedlearning\TS_FL_Grossload_Forecasting_Moe\../../..\utils\federatedrunner.py:255, in run_federated_benchmark_model(num_clusters, federated_rounds, cluster_users, save_path, wb_project_name, wb_project, wb_model_name, df_array, max_epochs, batch_size, X_train, horizon, loss, metrics, y_train, X_val, y_val, X_test, y_test, callbacks, layers, lstm_units, cnn_filter, cnn_kernel_size, cnn_dense_units, transformer_dense_units, sequence_length, transformer_num_features, transformer_num_heads, soft_lstm_units, soft_lstm_num_experts, soft_lstm_expert_units, topk_lstm_units, topk_lstm_num_experts, topk_bilstm, topk_lstm_expert_units, soft_dense_units, soft_dense_expert_units, soft_dense_num_experts, topk_dense_units, topk_dense_num_experts, topk_dense, topk_dense_expert_units)
#     253 local_model.set_weights(global_model_weights)
#     254 #Fit local model to local data
# --> 255 histroy, user_results = fit_evaluate_model(
#     256     model=local_model,
#     257     X_train=X_train[f'user{user_index}'],
#     258     y_train = y_train[f'user{user_index}'],
#     259     max_epochs = max_epochs,
#     260     batch_size=batch_size,
#     261     X_val=X_val[f'user{user_index}'],
#     262     y_val=y_val[f'user{user_index}'],
#     263     X_test=X_test[f'user{user_index}'],
#     264     y_test=y_test[f'user{user_index}'],
#     265     callbacks=callbacks,
#     266     user=f'user{user_index}',
#     267     hyper=wb_model_name,
#     268     optimizer=tf.keras.optimizers.Adam(learning_rate=0.0006),
#     269 )
#     271 #add model weights to list
#     272 local_model_weights = local_model.get_weights()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\src\time_series\Federatedlearning\TS_FL_Grossload_Forecasting_Moe\../../..\utils\datahandling.py:121, in fit_evaluate_model(model, X_train, y_train, max_epochs, batch_size, X_val, y_val, X_test, y_test, callbacks, user, hyper, optimizer)
#     118 wandb_callback = wandb.keras.WandbCallback(save_model=False)
#     120 # Train the model
# --> 121 history = model.fit(
#     122     X_train, y_train,
#     123     epochs=max_epochs,
#     124     batch_size=batch_size,
#     125     validation_data=(X_val, y_val),
#     126     callbacks=callbacks + [wandb_callback],
#     127     verbose=0,)
#     128 #Evaluate the model on test dataset
#     129 test_loss = model.evaluate(X_test, y_test, batch_size=batch_size, verbose=0)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#soft dense
run_federated_benchmark_model(
    num_clusters = num_clusters,
    federated_rounds = federated_rounds,
    cluster_users = cluster_users,
    save_path = os.getcwd(),
    wb_project_name = "TS_FL_Grossload_Forecasting_Moe",
    wb_project = "TS_FL_Grossload",
    wb_model_name = "global_soft_dense",
    df_array = df_array,
    max_epochs = max_epochs,
    batch_size = batch_size,
    X_train = X_train,
    horizon = horizon,
    loss = loss,
    metrics = metrics,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    soft_dense_units = dense_smoe_units, 
    soft_dense_num_experts = dense_smoe_num_experts,
    soft_dense_expert_units = dense_smoe_expert_units,
)
evaluate_federated_benchmark_model(
    federated_rounds = federated_rounds,
    save_path = os.getcwd(),
    wb_project = "TS_FL_Grossload",
    wb_model_name = "global_soft_dense",
    cluster_users = cluster_users,
    num_rounds = num_rounds,
    horizon = horizon,
    batch_size = batch_size,
    metrics = metrics,
    loss = loss,
    X_train = X_train,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    df_array = df_array,
    results = dense_smoe_results,
    all_results = dense_smoe_all_results,
    wb_project_name="TS_FL_Grossload_Forecasting_Moe",
    soft_dense_units = dense_smoe_units, 
    soft_dense_num_experts = dense_smoe_num_experts,
    soft_dense_expert_units = dense_smoe_expert_units,
)
# Out:
# Started Federated training round ---------- 1 / 2
# Cluster 0:
# got models
# User 7
# User 14
# User 18
# User 22
# User 23
# User 25
# User 29
# Saved Global models
# Cluster 1:
# got models
# User 6
# Saved Global models
# Cluster 2:
# got models
# User 3
# User 4
# User 9
# User 13
# User 15
# User 19
# User 20
# User 30
# Saved Global models
# Cluster 3:
# got models
# User 1
# Saved Global models
# Cluster 4:
# got models
# User 21
# Saved Global models
# Cluster 5:
# got models
# User 2
# User 28
# Saved Global models
# Cluster 6:
# got models
# User 5
# User 10
# User 11
# User 12
# User 24
# User 26
# User 27
# Saved Global models
# Cluster 7:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 #soft dense
# ----> 2 run_federated_benchmark_model(
#       3     num_clusters = num_clusters,
#       4     federated_rounds = federated_rounds,
#       5     cluster_users = cluster_users,
#       6     save_path = os.getcwd(),
#       7     wb_project_name = "TS_FL_Grossload_Forecasting_Moe",
#       8     wb_project = "TS_FL_Grossload",
#       9     wb_model_name = "global_soft_dense",
#      10     df_array = df_array,
#      11     max_epochs = max_epochs,
#      12     batch_size = batch_size,
#      13     X_train = X_train,
#      14     horizon = horizon,
#      15     loss = loss,
#      16     metrics = metrics,
#      17     y_train = y_train,
#      18     X_val = X_val,
#      19     y_val = y_val,
#      20     X_test = X_test,
#      21     y_test = y_test,
#      22     callbacks = callbacks,
#      23     soft_dense_units = dense_smoe_units,
#      24     soft_dense_num_experts = dense_smoe_num_experts,
#      25     soft_dense_expert_units = dense_smoe_expert_units,
#      26 )
#      27 evaluate_federated_benchmark_model(
#      28     federated_rounds = federated_rounds,
#      29     save_path = os.getcwd(),
#    (...)
#      51     soft_dense_expert_units = dense_smoe_expert_units,
#      52 )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\src\time_series\Federatedlearning\TS_FL_Grossload_Forecasting_Moe\../../..\utils\federatedrunner.py:157, in run_federated_benchmark_model(num_clusters, federated_rounds, cluster_users, save_path, wb_project_name, wb_project, wb_model_name, df_array, max_epochs, batch_size, X_train, horizon, loss, metrics, y_train, X_val, y_val, X_test, y_test, callbacks, layers, lstm_units, cnn_filter, cnn_kernel_size, cnn_dense_units, transformer_dense_units, sequence_length, transformer_num_features, transformer_num_heads, soft_lstm_units, soft_lstm_num_experts, soft_lstm_expert_units, topk_lstm_units, topk_lstm_num_experts, topk_bilstm, topk_lstm_expert_units, soft_dense_units, soft_dense_expert_units, soft_dense_num_experts, topk_dense_units, topk_dense_num_experts, topk_dense, topk_dense_expert_units)
#     151 #Get global models weights
#     152 custom_objects = {
#     153     'EinsumLayer': EinsumLayer,
#     154     'TopKLayer': TopKLayer,
#     155     'ImportanceRegularizationLayer': ImportanceRegularizationLayer
#     156     }
# --> 157 global_model = tf.keras.models.load_model(f'{save_path}/wandb/{wb_project}_{wb_model_name}_c{cluster_number}_FLround{federated_round}.keras', custom_objects=custom_objects, compile=False)
#     158 print("got models")
#     159 global_model_weights = global_model.get_weights()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\saving\saving_api.py:254, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     249     if kwargs:
#     250         raise ValueError(
#     251             "The following argument(s) are not supported "
#     252             f"with the native Keras format: {list(kwargs.keys())}"
#     253         )
# --> 254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
#     262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\saving\saving_lib.py:246, in load_model(filepath, custom_objects, compile, safe_mode)
#     244 # Construct the model from the configuration file in the archive.
#     245 with ObjectSharingScope():
# --> 246     model = deserialize_keras_object(
#     247         config_dict, custom_objects, safe_mode=safe_mode
#     248     )
#     250 all_filenames = zf.namelist()
#     251 if _VARS_FNAME + ".h5" in all_filenames:
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\saving\serialization_lib.py:728, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     726 safe_mode_scope = SafeModeScope(safe_mode)
#     727 with custom_obj_scope, safe_mode_scope:
# --> 728     instance = cls.from_config(inner_config)
#     729     build_config = config.get("build_config", None)
#     730     if build_config:
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\training.py:3330, in Model.from_config(cls, config, custom_objects)
#    3322 revivable_as_functional = (
#    3323     cls in {functional.Functional, Model}
#    3324     or argspec.args[1:] == functional_init_args
#    3325     or (argspec.varargs == "args" and argspec.varkw == "kwargs")
#    3326 )
#    3327 if is_functional_config and revivable_as_functional:
#    3328     # Revive Functional model
#    3329     # (but not Functional subclasses with a custom __init__)
# -> 3330     inputs, outputs, layers = functional.reconstruct_from_config(
#    3331         config, custom_objects
#    3332     )
#    3333     model = cls(
#    3334         inputs=inputs, outputs=outputs, name=config.get("name")
#    3335     )
#    3336     functional.connect_ancillary_layers(model, layers)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\functional.py:1505, in reconstruct_from_config(config, custom_objects, created_layers)
#    1503 while layer_nodes:
#    1504     node_data = layer_nodes[0]
# -> 1505     if process_node(layer, node_data):
#    1506         layer_nodes.pop(0)
#    1507     else:
#    1508         # If a node can't be processed, stop processing the
#    1509         # nodes of the current layer to maintain node ordering.
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\functional.py:1445, in reconstruct_from_config.<locals>.process_node(layer, node_data)
#    1438 if (
#    1439     not hasattr(layer, "_preserve_input_structure_in_config")
#    1440     or not layer._preserve_input_structure_in_config
#    1441 ):
#    1442     input_tensors = base_layer_utils.unnest_if_single_tensor(
#    1443         input_tensors
#    1444     )
# -> 1445 output_tensors = layer(input_tensors, **kwargs)
#    1447 # Update node index map.
#    1448 output_index = tf.nest.flatten(output_tensors)[
#    1449     0
#    1450 ]._keras_history.node_index
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\base_layer.py:1063, in Layer.__call__(self, *args, **kwargs)
#    1055 # Functional Model construction mode is invoked when `Layer`s are called
#    1056 # on symbolic `KerasTensor`s, i.e.:
#    1057 # >> inputs = tf.keras.Input(10)
#    1058 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#    1059 # >> model = tf.keras.Model(inputs, outputs)
#    1060 if _in_functional_construction_mode(
#    1061     self, inputs, args, kwargs, input_list
#    1062 ):
# -> 1063     return self._functional_construction_call(
#    1064         inputs, args, kwargs, input_list
#    1065     )
#    1067 # Maintains info about the `Layer.call` stack.
#    1068 call_context = base_layer_utils.call_context()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\base_layer.py:2593, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    2587 with call_context.enter(
#    2588     layer=self, inputs=inputs, build_graph=True, training=training_value
#    2589 ):
#    2590     # Check input assumptions set after layer building, e.g. input
#    2591     # shape.
#    2592     try:
# -> 2593         outputs = self._keras_tensor_symbolic_call(
#    2594             inputs, input_masks, args, kwargs
#    2595         )
#    2596     except TypeError as e:
#    2597         if "DictWrapper" in str(e):
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\base_layer.py:2439, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#    2435     return tf.nest.map_structure(
#    2436         keras_tensor.KerasTensor, output_signature
#    2437     )
#    2438 else:
# -> 2439     return self._infer_output_signature(
#    2440         inputs, args, kwargs, input_masks
#    2441     )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\base_layer.py:2498, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#    2496         self._maybe_build(inputs)
#    2497         inputs = self._maybe_cast_inputs(inputs)
# -> 2498         outputs = call_fn(inputs, *args, **kwargs)
#    2500     self._handle_activity_regularization(inputs, outputs)
#    2501 self._set_mask_metadata(
#    2502     inputs, outputs, input_masks, build_graph=False
#    2503 )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\layers\core\dense.py:244, in Dense.call(self, inputs)
#     241         outputs = tf.matmul(a=inputs, b=self.kernel)
#     242 # Broadcast kernel to inputs.
#     243 else:
# --> 244     outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#     245     # Reshape the output back to the original ndim of the input.
#     246     if not tf.executing_eagerly():
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\math_ops.py:5322, in tensordot(a, b, axes, name)
#    5320     return ab_matmul
#    5321   else:
# -> 5322     return array_ops.reshape(
#    5323         ab_matmul, a_free_dims + b_free_dims, name=name)
#    5324 else:
#    5325   a_free_dims = ops.convert_to_tensor(a_free_dims, dtype=dtypes.int32)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\array_ops.py:201, in reshape(tensor, shape, name)
#      65 @tf_export("reshape", v1=["reshape", "manip.reshape"])
#      66 @dispatch.add_dispatch_support
#      67 def reshape(tensor, shape, name=None):  # pylint: disable=redefined-outer-name
#      68   r"""Reshapes a tensor.
#      69
#      70   Given `tensor`, this operation returns a new `tf.Tensor` that has the same
#    (...)
#     199     A `Tensor`. Has the same type as `tensor`.
#     200   """
# --> 201   result = gen_array_ops.reshape(tensor, shape, name)
#     202   shape_util.maybe_set_static_shape(result, shape)
#     203   return result
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\gen_array_ops.py:8759, in reshape(tensor, shape, name)
#    8757     pass  # Add nodes to the TensorFlow graph.
#    8758 # Add nodes to the TensorFlow graph.
# -> 8759 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    8760       "Reshape", tensor=tensor, shape=shape, name=name)
#    8761 _result = _outputs[:]
#    8762 if _execute.must_record_gradient():
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\op_def_library.py:778, in _apply_op_helper(op_type_name, name, **keywords)
#     776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
# --> 778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#     781     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                            default_type_attr_map, attrs)
#     783     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\op_def_library.py:531, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     529 inferred = None
#     530 try:
# --> 531   inferred = ops.convert_to_tensor(
#     532       values, name=input_arg.name, as_ref=input_arg.is_ref)
#     533 except TypeError as err:
#     534   # When converting a python object such as a list of Dimensions, we
#     535   # need a dtype to be specified, thus tensor conversion may throw
#     536   # an exception which we will ignore and try again below.
#     537   pass
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:696, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     694 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     695 preferred_dtype = preferred_dtype or dtype_hint
# --> 696 return tensor_conversion_registry.convert(
#     697     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     698 )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:335, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     332 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     333                                          as_ref=False):
#     334   _ = as_ref
# --> 335   return constant(v, dtype=dtype, name=name)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:271, in constant(value, dtype, shape, name)
#     172 @tf_export("constant", v1=[])
#     173 def constant(
#     174     value, dtype=None, shape=None, name="Const"
#     175 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     176   """Creates a constant tensor from a tensor-like object.
#     177
#     178   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\constant_op.py:286, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     283       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 286 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     287     value, dtype, shape, name, verify_shape, allow_broadcast
#     288 )
#     289 return const_tensor
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:268, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     266 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     267 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 268 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     269     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     271 if op_callbacks.should_invoke_op_callbacks():
#     272   # TODO(b/147670703): Once the special-op creation code paths
#     273   # are unified. Remove this `if` block.
#     274   callback_outputs = op_callbacks.invoke_op_callbacks(
#     275       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:2652, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2649 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2650 # Session.run call cannot occur between creating and mutating the op.
#    2651 with self._mutation_lock():
# -> 2652   ret = Operation.from_node_def(
#    2653       node_def,
#    2654       self,
#    2655       inputs=inputs,
#    2656       output_types=dtypes,
#    2657       control_inputs=control_inputs,
#    2658       input_types=input_types,
#    2659       original_op=self._default_original_op,
#    2660       op_def=op_def,
#    2661   )
#    2662   self._create_op_helper(ret, compute_device=compute_device)
#    2663 return ret
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:1160, in Operation.from_node_def(***failed resolving arguments***)
#    1157     control_input_ops.append(control_op)
#    1159 # Initialize c_op from node_def and other inputs
# -> 1160 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1161 self = Operation(c_op, SymbolicTensor)
#    1162 self._init(g)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:1017, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1013   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1014                                          serialized)
#    1016 try:
# -> 1017   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1018 except errors.InvalidArgumentError as e:
#    1019   # Convert to ValueError for backwards compatibility.
#    1020   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
#topk dense
run_federated_benchmark_model(
    num_clusters = num_clusters,
    federated_rounds = federated_rounds,
    cluster_users = cluster_users,
    save_path = os.getcwd(),
    wb_project_name = "TS_FL_Grossload_Forecasting_Moe",
    wb_project = "TS_FL_Grossload",
    wb_model_name = "global_topk_dense",
    df_array = df_array,
    max_epochs = max_epochs,
    batch_size = batch_size,
    X_train = X_train,
    horizon = horizon,
    loss = loss,
    metrics = metrics,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    topk_dense_units = dense_topmoe_units, 
    topk_dense_num_experts = dense_topmoe_num_experts,
    topk_dense_expert_units = dense_topmoe_expert_units,
    topk_dense = dense_topmoe_top_k,
)

evaluate_federated_benchmark_model(
    federated_rounds = federated_rounds,
    save_path = os.getcwd(),
    wb_project = "TS_FL_Grossload",
    wb_model_name = "global_soft_bilstm",
    cluster_users = cluster_users,
    num_rounds = num_rounds,
    horizon = horizon,
    batch_size = batch_size,
    metrics = metrics,
    loss = loss,
    X_train = X_train,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    df_array = df_array,
    results = dense_topmoe_results,
    all_results = dense_topmoe_all_results,
    wb_project_name="TS_FL_Grossload_Forecasting_Moe",
    topk_dense_units = dense_topmoe_units, 
    topk_dense_num_experts = dense_topmoe_num_experts,
    topk_dense_expert_units = dense_topmoe_expert_units,
    topk_dense = dense_topmoe_top_k,
)
