# %%
#Imports
import pandas as pd
import os
import tensorflow as tf

import sys  
sys.path.append("../../../")  
from utils.models import *
from utils.datahandling import *
from utils.modelrunner import *

import wandb
import logging
logging.getLogger("wandb").setLevel(logging.ERROR)
logging.getLogger('tensorflow').setLevel(logging.ERROR)

os.environ['WANDB_SILENT'] = 'true'
os.environ['WANDB_CONSOLE'] = 'off'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Out:
# WARNING:tensorflow:From c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Data processing

# %%
#Get data 
num_users = 30

cwd = os.path.normpath(os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))))
df = pd.read_csv(cwd+'/data/3final_data/Final_PV_dataset.csv', index_col='Date')
df.index = pd.to_datetime(df.index)
df.fillna(0, inplace=True)

# Get the first date from the index
start_date = df.index.min()
# Calculate the end date as one year from the start date
end_date = start_date + pd.DateOffset(years=1)
# Filter the dataframe to only include the first year of data
df = df[(df.index >= start_date) & (df.index < end_date)]

df_array = []
for idx in range(num_users):
    df_array.append(df[[f'User{idx+1}', 'temp', 'rhum', 'wspd', 'PC1', 'hour sin', 'hour cos', f'User{idx+1}_lag_24hrs']])

df_array[0].head(1)
# Out:
#             User1  temp  rhum  wspd       PC1  hour sin  hour cos  \
# Date
# 2010-07-02    0.0   2.5  92.0   0.0 -2.641741       0.0       1.0
#
#             User1_lag_24hrs
# Date
# 2010-07-02              0.0

# %%
#Hyperparameters
sequence_length = 25
batch_size = 16
num_features = df_array[0].shape[1]
horizon = 1
max_epochs = 100

loss = tf.keras.losses.MeanSquaredError()
metrics=[
    tf.keras.metrics.RootMeanSquaredError(), 
    tf.keras.metrics.MeanAbsolutePercentageError(),
    tf.keras.metrics.MeanAbsoluteError(),
]

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10,mode='min')
timing_callback = TimingCallback()
custom_callback = CustomCallback()

callbacks=[early_stopping, timing_callback, custom_callback]

#BiLSTM
lstm_architecture = "L2_U8"
lstm_layers = 2
lstm_units = 8
lstm_all_results = pd.DataFrame(columns=["user", "architecture", "train_time", "avg_time_epoch", "mse", "rmse", "mape", "mae"])
lstm_results = pd.DataFrame(columns=['architecture', 'train_time', 'avg_time_epoch', 'mse','mse_std', 'rmse','rmse_std','mape','mape_std','mae','mae_std'])

#CNN
cnn_architecture = "CNN_Model"
cnn_layers = 4
cnn_kernel_size = 1
cnn_filter_size = 8
cnn_dense_units = 16
cnn_all_results = pd.DataFrame(columns=["user", "architecture", "train_time", "avg_time_epoch", "mse", "rmse", "mape", "mae"])
cnn_results = pd.DataFrame(columns=['architecture', 'train_time', 'avg_time_epoch', 'mse','mse_std', 'rmse','rmse_std','mape','mape_std','mae','mae_std'])

#Transfotransformer_architecture = "Transformer_ED2_h4_d32"
transformer_layers = 2
transformer_heads = 4
transformer_dense_units = 16
transformer_all_results = pd.DataFrame(columns=["user", "architecture", "train_time", "avg_time_epoch", "mse", "rmse", "mape", "mae"])
transformer_results = pd.DataFrame(columns=['architecture', 'train_time', 'avg_time_epoch', 'mse','mse_std', 'rmse','rmse_std','mape','mape_std','mae','mae_std'])

# %%
#Train, Validation and Test datasets
X_train, y_train, X_val, y_val, X_test, y_test = {}, {}, {}, {}, {}, {}

#Create Train, Validation and Test datasets
for idx, df in enumerate(df_array):
    n = len(df)
    train_df = df[0:int(n*0.7)]
    val_df = df[int(n*0.7):int(n*0.9)]
    test_df = df[int(n*0.9):]

    # Min max sclaing
    train_df = min_max_scaling(train_df)
    val_df = min_max_scaling(val_df)
    test_df = min_max_scaling(test_df)

    # Sequencing
    train_sequences = create_sequences(train_df, sequence_length)
    val_sequences = create_sequences(val_df, sequence_length)
    test_sequences = create_sequences(test_df, sequence_length)

    #Split into feature and label
    X_train[f'user{idx+1}'], y_train[f'user{idx+1}'] = prepare_data(train_sequences, batch_size)
    X_val[f'user{idx+1}'], y_val[f'user{idx+1}'] = prepare_data(val_sequences, batch_size)
    X_test[f'user{idx+1}'], y_test[f'user{idx+1}'] = prepare_data(test_sequences, batch_size)

# %% [markdown]
# # Benchmark Models

# %%
run_bilstm_model(
    wb_project_name = "TS_LL_PV_Forecasting_Benchmark",
    wb_model_name = "bilstm",
    wb_project = "TS_LL_PV",
    save_path = os.getcwd(),
    df_array = df_array,
    max_epochs = max_epochs,
    batch_size = batch_size,
    X_train = X_train,
    horizon = horizon, 
    lstm_layers = lstm_layers, 
    lstm_units = lstm_units,    
    metrics = metrics,
    loss = loss,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    results = lstm_results,
    all_results = lstm_all_results
)
# Out:
# -----User:  1
# Round:  0
# saved model
# Round:  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run_bilstm_model(
#       2     wb_project_name = "TS_LL_PV_Forecasting_Benchmark",
#       3     wb_model_name = "bilstm",
#       4     wb_project = "TS_LL_PV",
#       5     save_path = os.getcwd(),
#       6     df_array = df_array,
#       7     max_epochs = max_epochs,
#       8     batch_size = batch_size,
#       9     X_train = X_train,
#      10     horizon = horizon,
#      11     lstm_layers = lstm_layers,
#      12     lstm_units = lstm_units,
#      13     metrics = metrics,
#      14     loss = loss,
#      15     y_train = y_train,
#      16     X_val = X_val,
#      17     y_val = y_val,
#      18     X_test = X_test,
#      19     y_test = y_test,
#      20     callbacks = callbacks,
#      21     results = lstm_results,
#      22     all_results = lstm_all_results,
#      23     num_rounds=2
#      24 )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\src\time_series\Locallearning\TS_LL_PV_Forecasting_Benchmark\../../..\utils\modelrunner.py:47, in run_bilstm_model(wb_project_name, wb_model_name, wb_project, save_path, df_array, max_epochs, batch_size, X_train, horizon, lstm_layers, lstm_units, metrics, loss, y_train, X_val, y_val, X_test, y_test, callbacks, results, all_results, num_rounds)
#      36 wandb.init(project=wb_project_name,
#      37     name=f'{wb_model_name}_u{idx+1}_rd{round+1}',
#      38     config={
#    (...)
#      43     'architecture': wb_model_name,
#      44 })
#      46 model = build_bilstm_model(X_train[f'user{idx+1}'], horizon, num_layers=lstm_layers, units=lstm_units, batch_size=batch_size)
# ---> 47 histroy, user_results = compile_fit_evaluate_model(
#      48     model=model,
#      49     loss=loss,
#      50     metrics=metrics,
#      51     X_train=X_train[f'user{idx+1}'],
#      52     y_train = y_train[f'user{idx+1}'],
#      53     max_epochs = max_epochs,
#      54     batch_size=batch_size,
#      55     X_val=X_val[f'user{idx+1}'],
#      56     y_val=y_val[f'user{idx+1}'],
#      57     X_test=X_test[f'user{idx+1}'],
#      58     y_test=y_test[f'user{idx+1}'],
#      59     callbacks=callbacks,
#      60     user=f'user{idx+1}',
#      61     hyper=wb_model_name,
#      62     optimizer=tf.keras.optimizers.Adam(learning_rate=0.001)
#      63 )
#      64 # Add the 'architecture' column from dense_user_results to dense_results
#      65 all_results = pd.merge(all_results, user_results, how='outer')
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\src\time_series\Locallearning\TS_LL_PV_Forecasting_Benchmark\../../..\utils\datahandling.py:114, in compile_fit_evaluate_model(model, loss, metrics, X_train, y_train, max_epochs, batch_size, X_val, y_val, X_test, y_test, callbacks, user, hyper, optimizer)
#     111 wandb_callback = wandb.keras.WandbCallback(save_model=False)
#     113 # Train the model
# --> 114 history = model.fit(
#     115     X_train, y_train,
#     116     epochs=max_epochs,
#     117     batch_size=batch_size,
#     118     validation_data=(X_val, y_val),
#     119     callbacks=callbacks + [wandb_callback],
#     120     verbose=0,)
#     122 #Evaluate the model on test dataset
#     123 test_loss = model.evaluate(X_test, y_test, batch_size=batch_size, verbose=0)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:888, in Function._call(self, *args, **kwds)
#     885 try:
#     886   # This is the first call of __call__, so we have to initialize.
#     887   initializers = []
# --> 888   self._initialize(args, kwds, add_initializers_to=initializers)
#     889 finally:
#     890   # At this point we know that the initialization is complete (or less
#     891   # interestingly an exception was raised) so we no longer need a lock.
#     892   self._lock.release()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:695, in Function._initialize(self, args, kwds, add_initializers_to)
#     690 self._variable_creation_config = self._generate_scoped_tracing_options(
#     691     variable_capturing_scope,
#     692     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     693 )
#     694 # Force the definition of the function for these arguments
# --> 695 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696     args, kwds, self._variable_creation_config
#     697 )
#     699 def invalid_creator_scope(*unused_args, **unused_kwds):
#     700   """Disables variable creation."""
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:598, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     594 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     595   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     596   # the function a weak reference to itself to avoid a reference cycle.
#     597   with OptionalXlaContext(compile_with_xla):
# --> 598     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599   return out
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filerbzhm7uw.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:460, in _call_unconverted(f, args, kwargs, options, update_cache)
#     458 if kwargs is not None:
#     459   return f(*args, **kwargs)
# --> 460 return f(*args)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\training.py:1384, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1380     run_step = tf.function(
#    1381         run_step, jit_compile=True, reduce_retracing=True
#    1382     )
#    1383 data = next(iterator)
# -> 1384 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1385 outputs = reduce_per_replica(
#    1386     outputs,
#    1387     self.distribute_strategy,
#    1388     reduction=self.distribute_reduction_method,
#    1389 )
#    1390 return outputs
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1681, in StrategyBase.run(***failed resolving arguments***)
#    1676 with self.scope():
#    1677   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1678   # applied when the caller is also in Eager mode.
#    1679   fn = autograph.tf_convert(
#    1680       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1681   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3271, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3269   kwargs = {}
#    3270 with self._container_strategy().scope():
# -> 3271   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4069, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4067 def _call_for_each_replica(self, fn, args, kwargs):
#    4068   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4069     return fn(*args, **kwargs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\training.py:1373, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1372 def run_step(data):
# -> 1373     outputs = model.train_step(data)
#    1374     # Ensure counter is updated only if `train_step` succeeds.
#    1375     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\engine\training.py:1154, in Model.train_step(self, data)
#    1152 self._validate_target_and_loss(y, loss)
#    1153 # Run backwards pass.
# -> 1154 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#    1155 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\optimizers\optimizer.py:543, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     522 def minimize(self, loss, var_list, tape=None):
#     523     """Minimize `loss` by updating `var_list`.
#     524
#     525     This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     541       None
#     542     """
# --> 543     grads_and_vars = self.compute_gradients(loss, var_list, tape)
#     544     self.apply_gradients(grads_and_vars)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\keras\src\optimizers\optimizer.py:276, in _BaseOptimizer.compute_gradients(self, loss, var_list, tape)
#     273         if callable(var_list):
#     274             var_list = var_list()
# --> 276 grads = tape.gradient(loss, var_list)
#     277 return list(zip(grads, var_list))
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\backprop.py:1066, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1060   output_gradients = (
#    1061       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1062           output_gradients))
#    1063   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1064                       for x in output_gradients]
# -> 1066 flat_grad = imperative_grad.imperative_grad(
#    1067     self._tape,
#    1068     flat_targets,
#    1069     flat_sources,
#    1070     output_gradients=output_gradients,
#    1071     sources_raw=flat_sources_raw,
#    1072     unconnected_gradients=unconnected_gradients)
#    1074 if not self._persistent:
#    1075   # Keep track of watched variables before setting tape to None
#    1076   self._watched_variables = self._tape.watched_variables()
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:311, in _DelayedRewriteGradientFunctions._backward.<locals>._backward_function(*args)
#     309 def _backward_function(*args):
#     310   call_op = outputs[0].op
# --> 311   return self._rewrite_forward_and_call_backward(call_op, *args)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:212, in _DelayedRewriteGradientFunctions._rewrite_forward_and_call_backward(self, op, *doutputs)
#     210 def _rewrite_forward_and_call_backward(self, op: ops.Operation, *doutputs):
#     211   """Add outputs to the forward call and feed them to the grad function."""
# --> 212   forward_function, backwards_function = self.forward_backward(len(doutputs))
#     213   if not backwards_function.outputs:
#     214     return backwards_function.structured_outputs
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:145, in _DelayedRewriteGradientFunctions.forward_backward(self, num_doutputs)
#     143 if forward_backward is not None:
#     144   return forward_backward
# --> 145 forward, backward = self._construct_forward_backward(num_doutputs)
#     146 self._cached_function_pairs[num_doutputs] = (forward, backward)
#     147 return forward, backward
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:188, in _DelayedRewriteGradientFunctions._construct_forward_backward(self, num_doutputs)
#     185 with self._func_graph.as_default():
#     186   backwards_graph = func_graph_module.FuncGraph(
#     187       _backward_name(self._func_graph.name))
# --> 188   func_graph_module.func_graph_from_py_func(
#     189       name=backwards_graph.name,
#     190       python_func=_backprop_function,
#     191       args=[], kwargs={},
#     192       signature=signature,
#     193       func_graph=backwards_graph)
#     194   backwards_graph_captures = backwards_graph.external_captures
#     195   captures_from_forward = [
#     196       c for c in backwards_graph_captures if
#     197       not isinstance(c, ops.EagerTensor) and c.graph is self._func_graph]
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:179, in _DelayedRewriteGradientFunctions._construct_forward_backward.<locals>._backprop_function(*grad_ys)
#     177 def _backprop_function(*grad_ys):
#     178   with ops.device(None):
# --> 179     return gradients_util._GradientsHelper(  # pylint: disable=protected-access
#     180         trainable_outputs,
#     181         self._func_graph.inputs,
#     182         grad_ys=grad_ys,
#     183         src_graph=self._func_graph)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\gradients_util.py:733, in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     728 with src_graph._original_op(op):
#     729   # pylint: enable=protected-access
#     730   if grad_fn:
#     731     # If grad_fn was found, do not use SymbolicGradient even for
#     732     # functions.
# --> 733     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     734                              lambda: grad_fn(op, *out_grads))
#     735   else:
#     736     # For function call ops, we add a 'SymbolicGradient'
#     737     # node to the graph to compute gradients.
#     738     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     739                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\gradients_util.py:365, in _MaybeCompile(scope, op, func, grad_fn)
#     362     xla_compile = False
#     364 if not xla_compile:
# --> 365   return grad_fn()  # Exit early
#     367 # If the gradients are supposed to be compiled separately, we give them a
#     368 # _XlaScope name that is based on the name_scope of the gradients.  Otherwise
#     369 # they just inherit the existing _XlaScope name, which lets them be merged
#     370 # together with the non-gradient computation.
#     371 if xla_separate_compiled_gradients:
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\gradients_util.py:734, in _GradientsHelper.<locals>.<lambda>()
#     728 with src_graph._original_op(op):
#     729   # pylint: enable=protected-access
#     730   if grad_fn:
#     731     # If grad_fn was found, do not use SymbolicGradient even for
#     732     # functions.
#     733     in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 734                              lambda: grad_fn(op, *out_grads))
#     735   else:
#     736     # For function call ops, we add a 'SymbolicGradient'
#     737     # node to the graph to compute gradients.
#     738     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     739                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\while_v2.py:369, in _WhileGrad(op, *grads)
#     363 # We compute the gradient for the sub-graph between trainable ys and xs
#     364 # with non-None incoming gradients. We later pad the None's to the list of
#     365 # outputs.
#     366 ys, xs, non_none_grads = zip(*[(y, x, grad) for (y, x, grad) in zip(
#     367     body_graph.outputs, body_graph.inputs, grads) if grad is not None])
# --> 369 body_grad_graph, args = _create_grad_func(
#     370     ys, xs, non_none_grads, cond_graph, body_graph,
#     371     util.unique_grad_fn_name(body_graph.name), op, maximum_iterations)
#     373 if body_grad_graph.while_op_needs_rewrite:
#     374   # Modify 'op' to output the intermediate accumulators needed by the grad
#     375   # function.
#     376   # NOTE(skyewm): if there are any active sessions, this modification to `op`
#     377   # may make them unrunnable!
#     379   cond_graph.name += "_rewritten"
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\while_v2.py:665, in _create_grad_func(ys, xs, grads, cond_graph, body_graph, name, while_op, maximum_iterations)
#     662 args = [counter, maximum_iterations, total_iters] + list(grads)
#     663 # Note: The returned function does not have `args` in the list of
#     664 # `external_captures`.
# --> 665 grad_func_graph = func_graph_module.func_graph_from_py_func(
#     666     name,
#     667     lambda *args: _grad_fn(ys, xs, args, body_graph),
#     668     args, {},
#     669     func_graph=_WhileBodyGradFuncGraph(name, cond_graph, body_graph,
#     670                                        maximum_iterations, while_op,
#     671                                        body_graph_inputs, body_graph_outputs))
#     673 # Update the list of outputs with tensors corresponding to the captured
#     674 # tensors. We capture 3 types of tensors when building the grad fn:
#     675 # 1. Accumulators for forward graph intermediates which are not loop
#    (...)
#     678 # 2. Resources, which are output as is.
#     679 # 3. Forward graph loop invariants, which are output as is.
#     680 for external_capture, internal_capture in grad_func_graph.captures:
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\while_v2.py:667, in _create_grad_func.<locals>.<lambda>(*args)
#     662 args = [counter, maximum_iterations, total_iters] + list(grads)
#     663 # Note: The returned function does not have `args` in the list of
#     664 # `external_captures`.
#     665 grad_func_graph = func_graph_module.func_graph_from_py_func(
#     666     name,
# --> 667     lambda *args: _grad_fn(ys, xs, args, body_graph),
#     668     args, {},
#     669     func_graph=_WhileBodyGradFuncGraph(name, cond_graph, body_graph,
#     670                                        maximum_iterations, while_op,
#     671                                        body_graph_inputs, body_graph_outputs))
#     673 # Update the list of outputs with tensors corresponding to the captured
#     674 # tensors. We capture 3 types of tensors when building the grad fn:
#     675 # 1. Accumulators for forward graph intermediates which are not loop
#    (...)
#     678 # 2. Resources, which are output as is.
#     679 # 3. Forward graph loop invariants, which are output as is.
#     680 for external_capture, internal_capture in grad_func_graph.captures:
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\while_v2.py:722, in _grad_fn(ys, xs, args, func_graph)
#     715 grad_ys = args[3:]
#     717 # Build the gradient graph. Note that this builds the gradient computation of
#     718 # func_graph in the current graph, which requires capturing tensors from
#     719 # func_graph. The captured func_graph tensors are resolved to external tensors
#     720 # after the forward While op has been rewritten in _resolve_grad_captures.
#     721 # TODO(srbs): Mark GradientsHelper as public?
# --> 722 grad_outs = gradients_util._GradientsHelper(
#     723     ys, xs, grad_ys=grad_ys, src_graph=func_graph,
#     724     unconnected_gradients="zero")
#     726 # TODO(b/118712257): Handle the case when grad_outs has None's e.g. when there
#     727 # is a tf.StopGradient in the loop body.
#     728 assert all(g is not None for g in grad_outs)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\gradients_util.py:733, in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     728 with src_graph._original_op(op):
#     729   # pylint: enable=protected-access
#     730   if grad_fn:
#     731     # If grad_fn was found, do not use SymbolicGradient even for
#     732     # functions.
# --> 733     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     734                              lambda: grad_fn(op, *out_grads))
#     735   else:
#     736     # For function call ops, we add a 'SymbolicGradient'
#     737     # node to the graph to compute gradients.
#     738     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     739                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\gradients_util.py:365, in _MaybeCompile(scope, op, func, grad_fn)
#     362     xla_compile = False
#     364 if not xla_compile:
# --> 365   return grad_fn()  # Exit early
#     367 # If the gradients are supposed to be compiled separately, we give them a
#     368 # _XlaScope name that is based on the name_scope of the gradients.  Otherwise
#     369 # they just inherit the existing _XlaScope name, which lets them be merged
#     370 # together with the non-gradient computation.
#     371 if xla_separate_compiled_gradients:
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\gradients_util.py:734, in _GradientsHelper.<locals>.<lambda>()
#     728 with src_graph._original_op(op):
#     729   # pylint: enable=protected-access
#     730   if grad_fn:
#     731     # If grad_fn was found, do not use SymbolicGradient even for
#     732     # functions.
#     733     in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 734                              lambda: grad_fn(op, *out_grads))
#     735   else:
#     736     # For function call ops, we add a 'SymbolicGradient'
#     737     # node to the graph to compute gradients.
#     738     in_grads = _MaybeCompile(grad_scope, op, func_call,
#     739                              lambda: _SymGrad(op, out_grads))
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\math_grad.py:1423, in _MulGrad(op, grad)
#    1417 x = op.inputs[0]
#    1418 if (
#    1419     isinstance(grad, tensor.Tensor)
#    1420     and _ShapesFullySpecifiedAndEqual(x, y, grad)
#    1421     and grad.dtype in (dtypes.int32, dtypes.float32)
#    1422 ):
# -> 1423   return gen_math_ops.mul(grad, y), gen_math_ops.mul(grad, x)
#    1424 assert x.dtype.base_dtype == y.dtype.base_dtype, (x.dtype, " vs. ", y.dtype)
#    1426 if 0 in skip_input_indices:
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6764, in mul(x, y, name)
#    6762     pass  # Add nodes to the TensorFlow graph.
#    6763 # Add nodes to the TensorFlow graph.
# -> 6764 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6765       "Mul", x=x, y=y, name=name)
#    6766 _result = _outputs[:]
#    6767 if _execute.must_record_gradient():
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\op_def_library.py:796, in _apply_op_helper(op_type_name, name, **keywords)
#     791 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     792                         if arg.is_ref]
#     793 with _MaybeColocateWith(must_colocate_inputs):
#     794   # Add Op to graph
#     795   # pylint: disable=protected-access
# --> 796   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     797                              name=scope, input_types=input_types,
#     798                              attrs=attr_protos, op_def=op_def)
#     800 # `outputs` is returned as a separate return value so that the output
#     801 # tensors can the `op` per se can be decoupled so that the
#     802 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     803 # for more details.
#     804 outputs = op.outputs
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\while_v2.py:1013, in _WhileBodyGradFuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     996 if (op_type in optimized_reduction_ops and
#     997     not util.output_all_intermediates() and
#     998     all(input.graph is self._forward_graph for input in inputs) and
#    (...)
#    1001     not util.graph_wrapped_for_higher_order_tape_gradients(
#    1002         self._forward_graph)):
#    1003   return self._move_op_to_forward_graph(
#    1004       op_type,
#    1005       inputs,
#    (...)
#    1010       op_def=op_def,
#    1011       compute_device=compute_device)
# -> 1013 return super(_WhileBodyGradFuncGraph, self)._create_op_internal(
#    1014     op_type,
#    1015     inputs,
#    1016     dtypes=dtypes,
#    1017     input_types=input_types,
#    1018     name=name,
#    1019     attrs=attrs,
#    1020     op_def=op_def,
#    1021     compute_device=compute_device)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:668, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     666   if ctxt is not None and hasattr(ctxt, "AddValue"):
#     667     inp = ctxt.AddValue(inp)
# --> 668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
#     670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:675, in FuncGraph.capture(self, tensor, name, shape)
#     674 def capture(self, tensor, name=None, shape=None):
# --> 675   return self._function_captures.capture_by_value(self, tensor, name)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\core\function\capture\capture_container.py:154, in FunctionCaptures.capture_by_value(self, graph, tensor, name)
#     151     name = tensor.op.name
#     152   # cond/while graphs override _capture_helper() so cannot call
#     153   # self.create_placeholder_helper() here directly.
# --> 154   return graph._capture_helper(tensor, name)  # pylint: disable=protected-access
#     155 return tensor
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\while_v2.py:1199, in _WhileBodyGradFuncGraph._capture_helper(self, tensor, name)
#    1194     self._forward_cond_graph.capture(tensor_list)
#    1196 # Capture the accumulator tensor list in the gradient graph directly from
#    1197 # the forward graph -- we'll later modify this to capture the final list
#    1198 # output by the forward While op instead.
# -> 1199 captured_accumulator = super(_WhileBodyGradFuncGraph, self)._capture_helper(
#    1200     accumulator, name)
#    1202 # Pop the intermediate value from the tensor list in the gradient graph.
#    1203 new_tensor_list, captured_tensor = list_ops.tensor_list_pop_back(
#    1204     captured_accumulator, element_dtype=tensor.dtype)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:706, in FuncGraph._capture_helper(self, tensor, name)
#     705 def _capture_helper(self, tensor, name):
# --> 706   return self._function_captures._create_placeholder_helper(  # pylint: disable=protected-access
#     707       self, tensor, name)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\core\function\capture\capture_container.py:285, in FunctionCaptures._create_placeholder_helper(self, graph, tensor, name)
#     279   composite_device_name = None
#     280 placeholder_ctx = trace_type.InternalPlaceholderContext(
#     281     graph,
#     282     with_none_control_dependencies=True,
#     283     composite_device_name=composite_device_name,
#     284 )
# --> 285 placeholder = spec.placeholder_value(placeholder_ctx)
#     286 self.add_or_replace(
#     287     key=id(tensor), external=tensor, internal=placeholder, is_by_ref=False
#     288 )
#     289 graph.inputs.append(placeholder)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\tensor.py:1020, in TensorSpec.placeholder_value(self, placeholder_context)
#    1016 if placeholder_context.with_none_control_dependencies:
#    1017   # Note: setting ops.control_dependencies(None) ensures we always put
#    1018   # capturing placeholders outside of any control flow context.
#    1019   with context_graph.control_dependencies(None):
# -> 1020     placeholder = self._graph_placeholder(context_graph, name=name)
#    1021 else:
#    1022   placeholder = self._graph_placeholder(context_graph, name=name)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\tensor.py:1060, in TensorSpec._graph_placeholder(self, graph, name)
#    1058 attrs = {"dtype": dtype_value, "shape": shape}
#    1059 try:
# -> 1060   op = graph._create_op_internal(  # pylint: disable=protected-access
#    1061       "Placeholder", [], [dtype], input_types=[],
#    1062       attrs=attrs, name=name)
#    1063 except ValueError as e:
#    1064   # TODO(b/262413656) Sometimes parameter names are not valid op names, in
#    1065   # which case an unnamed placeholder is created instead. Update this logic
#    1066   # to sanitize the name instead of falling back on unnamed placeholders.
#    1067   logging.warning(e)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\ops\while_v2.py:1013, in _WhileBodyGradFuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     996 if (op_type in optimized_reduction_ops and
#     997     not util.output_all_intermediates() and
#     998     all(input.graph is self._forward_graph for input in inputs) and
#    (...)
#    1001     not util.graph_wrapped_for_higher_order_tape_gradients(
#    1002         self._forward_graph)):
#    1003   return self._move_op_to_forward_graph(
#    1004       op_type,
#    1005       inputs,
#    (...)
#    1010       op_def=op_def,
#    1011       compute_device=compute_device)
# -> 1013 return super(_WhileBodyGradFuncGraph, self)._create_op_internal(
#    1014     op_type,
#    1015     inputs,
#    1016     dtypes=dtypes,
#    1017     input_types=input_types,
#    1018     name=name,
#    1019     attrs=attrs,
#    1020     op_def=op_def,
#    1021     compute_device=compute_device)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:2652, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2649 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2650 # Session.run call cannot occur between creating and mutating the op.
#    2651 with self._mutation_lock():
# -> 2652   ret = Operation.from_node_def(
#    2653       node_def,
#    2654       self,
#    2655       inputs=inputs,
#    2656       output_types=dtypes,
#    2657       control_inputs=control_inputs,
#    2658       input_types=input_types,
#    2659       original_op=self._default_original_op,
#    2660       op_def=op_def,
#    2661   )
#    2662   self._create_op_helper(ret, compute_device=compute_device)
#    2663 return ret
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:1160, in Operation.from_node_def(***failed resolving arguments***)
#    1157     control_input_ops.append(control_op)
#    1159 # Initialize c_op from node_def and other inputs
# -> 1160 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1161 self = Operation(c_op, SymbolicTensor)
#    1162 self._init(g)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\rs1044\Documents\GitHub\Mixture-of-Experts-based-Federated-Learning-for-Energy-Forecasting\.venv\Lib\site-packages\tensorflow\python\framework\ops.py:1017, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1013   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1014                                          serialized)
#    1016 try:
# -> 1017   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1018 except errors.InvalidArgumentError as e:
#    1019   # Convert to ValueError for backwards compatibility.
#    1020   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
run_cnn_model(
    wb_project_name = "TS_LL_PV_Forecasting_Benchmark",
    wb_model_name = "cnn",
    wb_project = "TS_LL_PV",
    save_path = os.getcwd(),
    df_array = df_array,
    max_epochs = max_epochs,
    batch_size = batch_size,
    X_train = X_train,
    horizon = horizon, 
    cnn_layers = cnn_layers, 
    cnn_filter_size = cnn_filter_size,
    cnn_kernel_size = cnn_kernel_size, 
    cnn_dense_units = cnn_dense_units,      
    metrics = metrics,
    loss = loss,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    results = cnn_results,
    all_results = cnn_all_results
)

# %%
run_transformer_model(
     wb_project_name = "TS_LL_PV_Forecasting_Benchmark",
    wb_model_name = "transformer",
    wb_project = "TS_LL_PV",
    save_path = os.getcwd(),
    df_array = df_array,
    max_epochs = max_epochs,
    batch_size = batch_size,
    X_train = X_train,
    horizon = horizon, 
    sequence_length = sequence_length, 
    transformer_layers = transformer_layers, 
    num_features = num_features, 
    transformer_heads = transformer_heads, 
    transformer_dense_units = transformer_dense_units,  
    metrics = metrics,
    loss = loss,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    X_test = X_test,
    y_test = y_test,
    callbacks = callbacks,
    results = transformer_results,
    all_results = transformer_all_results
)
